# %% [markdown]
# # Competitive Pokemon: A data-centric analysis on what makes a Pokemon viable.
#
# ### Jeremy Jubilee
#
#
# ## Introduction
#
# Since 1996, Pokemon has been touching the hearts of millions, selling over 240 million copies of the main franchise alone. Cute mascots combined with simple, rewarding gameplay loops provide an enjoyable experience for every type of player. Surprisingly, these cute pokemon hide a deep, mathematical world underneath them. The mechanics of pokemon have always been complex, but abstracted enough such that they don’t hold too much of a bearing for casual players. However, for the hardcore, optimization of Pokemon gameplay is a rich experience.
#
# #### If you know a decent amount about Pokemon, you can skip this section and hop right into the [data collection!](#data_collection_raw)
# In competitive Pokemon, players build a team of 6 pokemon and have them battle each other. In single battles, Pokemon come out one at a time, and in double battles, they come out two at a time. Pokemon
# First, let's talk about what a pokemon is in terms of data that is important to a competitive player.
#
# Every Pokemon has 6 stats, one or two types, a pool of abilities, and a pool of moves.
#
# The 6 stats are as follows:
#
# **Health Points (HP):** Health Points indicate the amount of damage a pokemon can take before dying.
#
# **Attack (Atk):** Attack is related to damage for physical type moves. More attack is more damage dealt.
#
# **Defense (Def):** Defense is related to damage recieved for physical type moves. More defense is less damage taken.
#
# **Special Attack (SpA):** Special Attack is like attack, but for special type moves.
#
# **Special Defense (SpD):** Special Defense is like defense, but for special type moves.
#
# **Speed (Spe):** Speed determines the move order of pokemon. Pokemon with a higher speed stat go first.

# %% [markdown]
# <a id='data_collection_raw'></a>
# ## Data Collection: Scraping from APIs and HTML

# %%
from bs4 import BeautifulSoup as bs
import re
import requests
import json
import pandas as pd
import time
import numpy as np
from IPython.display import clear_output

# This is a flag that you should tick true if this is your first time running this. 
NEW_CSV_FLAG = False

# This flag is for debug output.
DEBUG_FLAG = True

# %%
if NEW_CSV_FLAG:
    pokemon_cols = ['dex_id', 'name', 'spe', 'spd', 'spa', 'dfn', 'atk', 'hp', 'type_1', 'type_2', 'move_list']
    df_pokemon = pd.DataFrame(columns = pokemon_cols)
    for i in range(1, 808):

        url = 'https://pokeapi.co/api/v2/pokemon/' + str(i)
        response = requests.get(url)

        cur_data = response.json() if response and response.status_code == 200 else None

        if cur_data == None:
            continue
        
        dex_id = cur_data['id']
        name = cur_data['name']
        spe = cur_data['stats'][0]['base_stat']
        spd = cur_data['stats'][1]['base_stat']
        spa = cur_data['stats'][2]['base_stat']
        dfn = cur_data['stats'][3]['base_stat']
        atk = cur_data['stats'][4]['base_stat']
        hp  = cur_data['stats'][5]['base_stat']
        # Check if current pokemon is monotype or dual-typed
        type_1 = cur_data['types'][0]['type']['name']
        if (len(cur_data['types']) == 2):
            type_2 = cur_data['types'][1]['type']['name']
        else:
            type_2 = np.nan

        move_list = []
        for j in range(0, len(cur_data['moves'])):
            move_list.append(cur_data['moves'][j]['move']['name'])

        # Make sure we don't overload the pokeAPI with requests!
        time.sleep(0.6)
        
        if DEBUG_FLAG:
            clear_output()
            print('Processing Pokedex Entry Number: ' + str(dex_id) + '; Name: ' + name)

        # Create and append our dataframe entry
        new_pokemon = pd.Series([dex_id, name, spe, spd, spa, dfn, atk, hp, type_1, type_2, move_list], index = pokemon_cols)
        df_pokemon = df_pokemon.append(new_pokemon, ignore_index = True)
    
    df_pokemon.to_csv('pokemon_list.csv')
else:
    
    # Don't request from the API
    df_pokemon = pd.read_csv('pokemon_list.csv')
    df_pokemon = df_pokemon.loc[:, ~df_pokemon.columns.str.contains('^Unnamed')]
    
df_pokemon.head(10)
# Out:
#               name  spe  spd  spa  dfn  atk  hp  type_1 type_2  \
# dex_id
# 1        bulbasaur   45   65   65   49   49  45  poison  grass
# 2          ivysaur   60   80   80   63   62  60  poison  grass
# 3         venusaur   80  100  100   83   82  80  poison  grass
# 4       charmander   65   50   60   43   52  39    fire    NaN
# 5       charmeleon   80   65   80   58   64  58    fire    NaN
# 6        charizard  100   85  109   78   84  78  flying   fire
# 7         squirtle   43   64   50   65   48  44   water    NaN
# 8        wartortle   58   80   65   80   63  59   water    NaN
# 9        blastoise   78  105   85  100   83  79   water    NaN
# 10        caterpie   45   20   20   35   30  45     bug    NaN
#
#                                                 move_list
# dex_id
# 1       ['razor-wind', 'swords-dance', 'cut', 'bind', ...
# 2       ['swords-dance', 'cut', 'bind', 'vine-whip', '...
# 3       ['swords-dance', 'cut', 'bind', 'vine-whip', '...
# 4       ['mega-punch', 'fire-punch', 'thunder-punch', ...
# 5       ['mega-punch', 'fire-punch', 'thunder-punch', ...
# 6       ['mega-punch', 'fire-punch', 'thunder-punch', ...
# 7       ['mega-punch', 'ice-punch', 'mega-kick', 'head...
# 8       ['mega-punch', 'ice-punch', 'mega-kick', 'head...
# 9       ['mega-punch', 'ice-punch', 'mega-kick', 'head...
# 10      ['tackle', 'string-shot', 'snore', 'bug-bite',...

# %%
# Out:
# Processing Pokedex Entry Number: 807; Name: zeraora
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-c1da96caaaf3> in <module>
#       6     cur_data = response.json() if response and response.status_code == 200 else None
#       7
# ----> 8     dex_id = cur_data['id']
#       9     name = cur_data['name']
#      10     spe = cur_data['stats'][0]['base_stat']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
if NEW_CSV_FLAG:
    response = requests.get('http://pokemondb.net/move/all')
    soup = bs(response.text, 'html.parser')
    tab = soup.find("table")
    tab_rows = tab.find_all('tr')
    move_cols = ['name', 'type', 'category', 'power', 'acc', 'pp', 'tm', 'effect', 'chance']
    df_moves = pd.DataFrame(columns = move_cols)
    for i in range(1, len(tab_rows)):
        tab_entries = tab_rows[i].find_all('td')
        
        # We do this to match the format of the moves 
        row = [t.text.lower().replace(' ','-') for t in tab_entries]
        row[2] = tab_entries[2]['data-sort-value']
        new_move = pd.Series(row, index = move_cols)
        df_moves = df_moves.append(new_move, ignore_index = True)
    df_moves.to_csv('moves_list.csv')
else:
    
    # Don't scrape from HTML
    df_moves = pd.read_csv('moves_list.csv')
    df_moves = df_moves.loc[:, ~df_moves.columns.str.contains('^Unnamed')]

df_moves.head(10)
# Out:
#                                  type  category power  acc  pp    tm  \
# name
# 10,000,000-volt-thunderbolt  electric   special   195    —   1   NaN
# absorb                          grass   special    20  100  25   NaN
# accelerock                       rock  physical    40  100  20   NaN
# acid                           poison   special    40  100  30   NaN
# acid-armor                     poison    status     —    —  20   NaN
# acid-downpour                  poison       NaN     —    —   1   NaN
# acid-spray                     poison   special    40  100  20   NaN
# acrobatics                     flying  physical    55  100  15  tm62
# acupressure                    normal    status     —    —  30   NaN
# aerial-ace                     flying  physical    60    ∞  20  tm40
#
#                                                                         effect  \
# name
# 10,000,000-volt-thunderbolt                          pikachu-exclusive-z-move.
# absorb                        user-recovers-half-the-hp-inflicted-on-opponent.
# accelerock                                                 user-attacks-first.
# acid                                     may-lower-opponent's-special-defense.
# acid-armor                                      sharply-raises-user's-defense.
# acid-downpour                                              poison-type-z-move.
# acid-spray                          sharply-lowers-opponent's-special-defense.
# acrobatics                   stronger-when-the-user-does-not-have-a-held-item.
# acupressure                                      sharply-raises-a-random-stat.
# aerial-ace                                   ignores-accuracy-and-evasiveness.
#
#                             chance
# name
# 10,000,000-volt-thunderbolt    NaN
# absorb                           —
# accelerock                     NaN
# acid                            10
# acid-armor                       —
# acid-downpour                  NaN
# acid-spray                     100
# acrobatics                       —
# acupressure                      —
# aerial-ace                       —

# %%
    
if NEW_CSV_FLAG == False:
    response = requests.get('https://pokemondb.net/ability')
    soup = bs(response.text, 'html.parser')
    tab = soup.find("tbody")
    tab_rows = tab.find_all('tr')
    abil_cols = ['name', 'pokemon_count', 'description', 'generation']
    df_abils = pd.DataFrame(columns = abil_cols)
    for i in range(1, len(tab_rows)):
        tab_entries = tab_rows[i].find_all('td')
        # We do this to match the format of the abilities 
        row = [t.text.lower().replace(' ','-') for t in tab_entries]
        new_abil = pd.Series(row, index = abil_cols)
        df_abils = df_abils.append(new_abil, ignore_index = True)
    df_abils.to_csv('abils_list.csv')
else:
    
    # Don't scrape from HTML
    df_abils = pd.read_csv('abils_list.csv')
    df_abils = df_abils.loc[:, ~df_abils.columns.str.contains('^Unnamed')]

df_abils.head(10)
# Out:
#            name pokemon_count  \
# 0      aerilate             2
# 1     aftermath             8
# 2      air-lock             1
# 3      analytic            12
# 4   anger-point             9
# 5  anticipation            15
# 6    arena-trap             3
# 7    aroma-veil             4
# 8    aura-break             2
# 9    bad-dreams             1
#
#                                          description generation
# 0    turns-normal-type-moves-into-flying-type-moves.          6
# 1    damages-the-attacker-landing-the-finishing-hit.          4
# 2                 eliminates-the-effects-of-weather.          3
# 3     boosts-move-power-when-the-pokémon-moves-last.          5
# 4          maxes-attack-after-taking-a-critical-hit.          4
# 5                    senses-a-foe's-dangerous-moves.          4
# 6                     prevents-the-foe-from-fleeing.          3
# 7  protects-allies-from-attacks-that-limit-their-...          6
# 8       reduces-power-of-dark--and-fairy-type-moves.          6
# 9                       reduces-a-sleeping-foe's-hp.          4

# %%
response = requests.get('http://smogon.com/dex/sm/pokemon')
soup = bs(response.text, 'html.parser')
script_string = soup.find('script').string

# %%
script_string = script_string.strip()
script_string = script_string.replace('dexSettings = ', '')

load = json.loads(script_string)
load.keys()
load = load['injectRpcs'][1][1]
smogon_pokemon = load['pokemon']

# %%
if NEW_CSV_FLAG:
    smog_cols = ['name', 'smogon_format', 'is_final_evo', 'abilities']
    df_smogon = pd.DataFrame(columns = smog_cols)
    for cur_poke in smogon_pokemon:
        try:
            name = cur_poke['name'].lower()
            smogon_format = np.nan
            is_final_evo = 1
            if (len(cur_poke['formats']) == 1):
                smogon_format = cur_poke['formats'][0]
            if (len(cur_poke['oob']['evos']) != 0):
                is_final_evo = 0
            abils = cur_poke['abilities']
            entries = [name, smogon_format, is_final_evo, abils]
            new_pokemon = pd.Series(entries, index = smog_cols)
            df_smogon = df_smogon.append(new_pokemon, ignore_index = True)
        except:
            ;
    df_smogon.to_csv('smogon_tiers.csv')
else:
    
    # Don't request from the API
    df_smogon = pd.read_csv('smogon_tiers.csv')
    df_smogon = df_smogon.loc[:, ~df_smogon.columns.str.contains('^Unnamed')]

df_smogon.head(5)
# Out:
#          name smogon_format is_final_evo                abilities
# 0   bulbasaur            LC            0  [Chlorophyll, Overgrow]
# 1     ivysaur           NaN            0  [Chlorophyll, Overgrow]
# 2    venusaur            RU            1  [Chlorophyll, Overgrow]
# 3  charmander            LC            0     [Blaze, Solar Power]
# 4  charmeleon           NaN            0     [Blaze, Solar Power]

# %% [markdown]
# ## Data Tidying!

# %%
df_final = pd.merge(df_pokemon, df_smogon, how = 'inner', on = ['name'])
df_final.head(10)
# Out:
#          name  spe  spd  spa  dfn  atk  hp  type_1 type_2  \
# 0   bulbasaur   45   65   65   49   49  45  poison  grass
# 1     ivysaur   60   80   80   63   62  60  poison  grass
# 2    venusaur   80  100  100   83   82  80  poison  grass
# 3  charmander   65   50   60   43   52  39    fire    NaN
# 4  charmeleon   80   65   80   58   64  58    fire    NaN
# 5   charizard  100   85  109   78   84  78  flying   fire
# 6    squirtle   43   64   50   65   48  44   water    NaN
# 7   wartortle   58   80   65   80   63  59   water    NaN
# 8   blastoise   78  105   85  100   83  79   water    NaN
# 9    caterpie   45   20   20   35   30  45     bug    NaN
#
#                                            move_list smogon_format  \
# 0  ['razor-wind', 'swords-dance', 'cut', 'bind', ...            LC
# 1  ['swords-dance', 'cut', 'bind', 'vine-whip', '...           NaN
# 2  ['swords-dance', 'cut', 'bind', 'vine-whip', '...            RU
# 3  ['mega-punch', 'fire-punch', 'thunder-punch', ...            LC
# 4  ['mega-punch', 'fire-punch', 'thunder-punch', ...           NaN
# 5  ['mega-punch', 'fire-punch', 'thunder-punch', ...          PUBL
# 6  ['mega-punch', 'ice-punch', 'mega-kick', 'head...            LC
# 7  ['mega-punch', 'ice-punch', 'mega-kick', 'head...           NaN
# 8  ['mega-punch', 'ice-punch', 'mega-kick', 'head...            NU
# 9  ['tackle', 'string-shot', 'snore', 'bug-bite',...            LC
#
#    is_final_evo
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0
# 5             1
# 6             0
# 7             0
# 8             1
# 9             0

# %%
df_final['smogon_format'].unique()
# Out:
# array(['LC', nan, 'RU', 'PUBL', 'NU', 'Untiered', 'UU', 'PU', 'OU',
#        'NUBL', 'RUBL', 'UUBL', 'Uber'], dtype=object)

# %%
smog_forms = ['LC','PU','NU','RU','UU','OU','Uber']
def bl_func(s):
    return "BL" in str(s)

def reform(s):
    s = str(s).replace('BL','')
    if s in smog_forms:
        return s
    else:
        return np.nan
        

formstats = df_final.copy()
formstats['is_BL'] = formstats['smogon_format'].map(lambda s: bl_func(s))
formstats['smogon_format'] = formstats['smogon_format'].map(lambda s: reform(s))
formstats['total_stats'] = formstats['spe']+formstats['spd']+formstats['spa']+formstats['dfn']+formstats['atk']+formstats['hp']

formstats = formstats.dropna(subset = ['smogon_format'])
formstats.head(10)
# Out:
#           name  spe  spd  spa  dfn  atk  hp  type_1  type_2  \
# 0    bulbasaur   45   65   65   49   49  45  poison   grass
# 2     venusaur   80  100  100   83   82  80  poison   grass
# 3   charmander   65   50   60   43   52  39    fire     NaN
# 5    charizard  100   85  109   78   84  78  flying    fire
# 6     squirtle   43   64   50   65   48  44   water     NaN
# 8    blastoise   78  105   85  100   83  79   water     NaN
# 9     caterpie   45   20   20   35   30  45     bug     NaN
# 12      weedle   50   20   20   30   35  40  poison     bug
# 15      pidgey   56   35   35   40   45  40  flying  normal
# 18     rattata   72   35   25   35   56  30  normal     NaN
#
#                                             move_list smogon_format  \
# 0   ['razor-wind', 'swords-dance', 'cut', 'bind', ...            LC
# 2   ['swords-dance', 'cut', 'bind', 'vine-whip', '...            RU
# 3   ['mega-punch', 'fire-punch', 'thunder-punch', ...            LC
# 5   ['mega-punch', 'fire-punch', 'thunder-punch', ...            PU
# 6   ['mega-punch', 'ice-punch', 'mega-kick', 'head...            LC
# 8   ['mega-punch', 'ice-punch', 'mega-kick', 'head...            NU
# 9   ['tackle', 'string-shot', 'snore', 'bug-bite',...            LC
# 12  ['poison-sting', 'string-shot', 'bug-bite', 'e...            LC
# 15  ['razor-wind', 'gust', 'wing-attack', 'whirlwi...            LC
# 18  ['cut', 'headbutt', 'tackle', 'body-slam', 'ta...            LC
#
#     is_final_evo  is_BL  total_stats
# 0              0  False          318
# 2              1  False          525
# 3              0  False          309
# 5              1   True          534
# 6              0  False          314
# 8              1  False          530
# 9              0  False          195
# 12             0  False          195
# 15             0  False          251
# 18             0  False          253

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import scipy.stats as stats
import matplotlib.gridspec as gridspec

colors = {False:'blue', True:'royalblue'}
fig, ax = plt.subplots(1,1, figsize = [15,10], sharey = True, sharex = True)
sns.set(style='whitegrid')
ax = sns.boxplot(x='smogon_format', y = 'total_stats', data = formstats, order = smog_forms, hue = 'is_BL', palette = colors)
ax.set_xlabel('Smogon Competitive Tier')
ax.legend(prop={'size': 15})
leg = ax.get_legend()
leg.set_title('Borderline in Tier')
fig.show()

# %%
fig, axs = plt.subplots(6,1, figsize = [15,30], sharey = True, sharex = True,
                        gridspec_kw = {'height_ratios':[1,1,1,1,1,1], 'hspace':0.005})
sns.set(style='whitegrid')
sns.boxplot(x='smogon_format', y = 'spe', data = formstats, hue = 'is_BL', ax = axs[0])
sns.boxplot(x='smogon_format', y = 'spd', data = formstats, hue = 'is_BL', ax = axs[1])
sns.boxplot(x='smogon_format', y = 'spa', data = formstats, hue = 'is_BL', ax = axs[2])
sns.boxplot(x='smogon_format', y = 'dfn', data = formstats, hue = 'is_BL', ax = axs[3])
sns.boxplot(x='smogon_format', y = 'atk', data = formstats, hue = 'is_BL', ax = axs[4])
sns.boxplot(x='smogon_format', y = 'hp' , data = formstats, hue = 'is_BL', ax = axs[5])

stats = ['spe','spd','spa','dfn','atk','hp']
stat_labels = ['Speed', 'Special Defense', 'Special Attack', 'Defense', 'Attack', 'Health Points']
axs[0].set_xlabel('')
axs[1].set_xlabel('')
axs[2].set_xlabel('')
axs[3].set_xlabel('')
axs[4].set_xlabel('')
axs[0].legend(title='Borderline in tier', loc='upper left', labels=['Borderline', 'Not Borderline'], markerfirst = False)

axs[len(axs) - 1].set_xlabel('Smogon Competitive Tier')
fig.show()

# %%
minhp = df_final['hp'].min()
maxhp = df_final['hp'].max()
smog_forms = ['LC','PU','NU','RU','UU','OU','Uber']
for form in smog_forms:
    health = lst.get_group(form)['hp'].values
    health = health.astype(int)
    density = stats.gaussian_kde(health)
    x = np.linspace(minhp, maxhp, 500)
    plt.plot(x, density(x))

    plt.show
# Out:
#      Unnamed: 0  dex_id         name  spe  spd  spa  dfn  atk  hp    type_1  \
# 0             0       1    bulbasaur   45   65   65   49   49  45    poison
# 1             1       2      ivysaur   60   80   80   63   62  60    poison
# 2             2       3     venusaur   80  100  100   83   82  80    poison
# 3             3       4   charmander   65   50   60   43   52  39      fire
# 4             4       5   charmeleon   80   65   80   58   64  58      fire
# ..          ...     ...          ...  ...  ...  ...  ...  ...  ..       ...
# 802         802     803      poipole   73   67   73   67   73  67    poison
# 803         803     804    naganadel  121   73  127   73   73  73    dragon
# 804         804     805    stakataka   13  101   53  211  131  61     steel
# 805         805     806  blacephalon  107   79  151   53  127  53     ghost
# 806         806     807      zeraora  143   80  102   75  112  88  electric
#
#      type_2                                          move_list
# 0     grass  ['razor-wind', 'swords-dance', 'cut', 'bind', ...
# 1     grass  ['swords-dance', 'cut', 'bind', 'vine-whip', '...
# 2     grass  ['swords-dance', 'cut', 'bind', 'vine-whip', '...
# 3       NaN  ['mega-punch', 'fire-punch', 'thunder-punch', ...
# 4       NaN  ['mega-punch', 'fire-punch', 'thunder-punch', ...
# ..      ...                                                ...
# 802     NaN  ['fury-attack', 'growl', 'acid', 'peck', 'toxi...
# 803  poison  ['fly', 'fury-attack', 'growl', 'acid', 'flame...
# 804    rock  ['tackle', 'take-down', 'double-edge', 'rock-t...
# 805    fire  ['ember', 'flamethrower', 'hyper-beam', 'toxic...
# 806     NaN  ['thunder-punch', 'scratch', 'thunderbolt', 't...
#
# [807 rows x 12 columns]

# %%
lst = df_final.groupby('smogon_format')

# %%
url = 'https://pokeapi.co/api/v2/pokemon/3'
response = requests.get(url)
cur_data = response.json()
cur_data['abilities']
# Out:
# [{'ability': {'name': 'chlorophyll',
#    'url': 'https://pokeapi.co/api/v2/ability/34/'},
#   'is_hidden': True,
#   'slot': 3},
#  {'ability': {'name': 'overgrow',
#    'url': 'https://pokeapi.co/api/v2/ability/65/'},
#   'is_hidden': False,
#   'slot': 1}]

# %%
load
# Out:
# {'pokemon': [{'name': 'Bulbasaur',
#    'hp': 45,
#    'atk': 49,
#    'def': 49,
#    'spa': 65,
#    'spd': 65,
#    'spe': 45,
#    'weight': 6.9,
#    'height': 0.7,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Overgrow'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 1,
#     'cap': False,
#     'evos': ['Ivysaur'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Ivysaur',
#    'hp': 60,
#    'atk': 62,
#    'def': 63,
#    'spa': 80,
#    'spd': 80,
#    'spe': 60,
#    'weight': 13,
#    'height': 1,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Overgrow'],
#    'formats': [],
#    'oob': {'dex_number': 2,
#     'cap': False,
#     'evos': ['Venusaur'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Venusaur',
#    'hp': 80,
#    'atk': 82,
#    'def': 83,
#    'spa': 100,
#    'spd': 100,
#    'spe': 80,
#    'weight': 100,
#    'height': 2,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Overgrow'],
#    'formats': ['RU'],
#    'oob': {'dex_number': 3,
#     'cap': False,
#     'evos': [],
#     'alts': ['Venusaur-Mega'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Charmander',
#    'hp': 39,
#    'atk': 52,
#    'def': 43,
#    'spa': 60,
#    'spd': 50,
#    'spe': 65,
#    'weight': 8.5,
#    'height': 0.6,
#    'types': ['Fire'],
#    'abilities': ['Blaze', 'Solar Power'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 4,
#     'cap': False,
#     'evos': ['Charmeleon'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Charmeleon',
#    'hp': 58,
#    'atk': 64,
#    'def': 58,
#    'spa': 80,
#    'spd': 65,
#    'spe': 80,
#    'weight': 19,
#    'height': 1.1,
#    'types': ['Fire'],
#    'abilities': ['Blaze', 'Solar Power'],
#    'formats': [],
#    'oob': {'dex_number': 5,
#     'cap': False,
#     'evos': ['Charizard'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Charizard',
#    'hp': 78,
#    'atk': 84,
#    'def': 78,
#    'spa': 109,
#    'spd': 85,
#    'spe': 100,
#    'weight': 90.5,
#    'height': 1.7,
#    'types': ['Fire', 'Flying'],
#    'abilities': ['Blaze', 'Solar Power'],
#    'formats': ['PUBL'],
#    'oob': {'dex_number': 6,
#     'cap': False,
#     'evos': [],
#     'alts': ['Charizard-Mega-Y', 'Charizard-Mega-X'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Squirtle',
#    'hp': 44,
#    'atk': 48,
#    'def': 65,
#    'spa': 50,
#    'spd': 64,
#    'spe': 43,
#    'weight': 9,
#    'height': 0.5,
#    'types': ['Water'],
#    'abilities': ['Rain Dish', 'Torrent'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 7,
#     'cap': False,
#     'evos': ['Wartortle'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Wartortle',
#    'hp': 59,
#    'atk': 63,
#    'def': 80,
#    'spa': 65,
#    'spd': 80,
#    'spe': 58,
#    'weight': 22.5,
#    'height': 1,
#    'types': ['Water'],
#    'abilities': ['Rain Dish', 'Torrent'],
#    'formats': [],
#    'oob': {'dex_number': 8,
#     'cap': False,
#     'evos': ['Blastoise'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Blastoise',
#    'hp': 79,
#    'atk': 83,
#    'def': 100,
#    'spa': 85,
#    'spd': 105,
#    'spe': 78,
#    'weight': 85.5,
#    'height': 1.6,
#    'types': ['Water'],
#    'abilities': ['Rain Dish', 'Torrent'],
#    'formats': ['NU'],
#    'oob': {'dex_number': 9,
#     'cap': False,
#     'evos': [],
#     'alts': ['Blastoise-Mega'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Caterpie',
#    'hp': 45,
#    'atk': 30,
#    'def': 35,
#    'spa': 20,
#    'spd': 20,
#    'spe': 45,
#    'weight': 2.9,
#    'height': 0.3,
#    'types': ['Bug'],
#    'abilities': ['Run Away', 'Shield Dust'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 10,
#     'cap': False,
#     'evos': ['Metapod'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Metapod',
#    'hp': 50,
#    'atk': 20,
#    'def': 55,
#    'spa': 25,
#    'spd': 25,
#    'spe': 30,
#    'weight': 9.9,
#    'height': 0.7,
#    'types': ['Bug'],
#    'abilities': ['Shed Skin'],
#    'formats': [],
#    'oob': {'dex_number': 11,
#     'cap': False,
#     'evos': ['Butterfree'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Butterfree',
#    'hp': 60,
#    'atk': 45,
#    'def': 50,
#    'spa': 90,
#    'spd': 80,
#    'spe': 70,
#    'weight': 32,
#    'height': 1.1,
#    'types': ['Bug', 'Flying'],
#    'abilities': ['Compound Eyes', 'Tinted Lens'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 12,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Weedle',
#    'hp': 40,
#    'atk': 35,
#    'def': 30,
#    'spa': 20,
#    'spd': 20,
#    'spe': 50,
#    'weight': 3.2,
#    'height': 0.3,
#    'types': ['Bug', 'Poison'],
#    'abilities': ['Run Away', 'Shield Dust'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 13,
#     'cap': False,
#     'evos': ['Kakuna'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Kakuna',
#    'hp': 45,
#    'atk': 25,
#    'def': 50,
#    'spa': 25,
#    'spd': 25,
#    'spe': 35,
#    'weight': 10,
#    'height': 0.6,
#    'types': ['Bug', 'Poison'],
#    'abilities': ['Shed Skin'],
#    'formats': [],
#    'oob': {'dex_number': 14,
#     'cap': False,
#     'evos': ['Beedrill'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Beedrill',
#    'hp': 65,
#    'atk': 90,
#    'def': 40,
#    'spa': 45,
#    'spd': 80,
#    'spe': 75,
#    'weight': 29.5,
#    'height': 1,
#    'types': ['Bug', 'Poison'],
#    'abilities': ['Sniper', 'Swarm'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 15,
#     'cap': False,
#     'evos': [],
#     'alts': ['Beedrill-Mega'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Pidgey',
#    'hp': 40,
#    'atk': 45,
#    'def': 40,
#    'spa': 35,
#    'spd': 35,
#    'spe': 56,
#    'weight': 1.8,
#    'height': 0.3,
#    'types': ['Normal', 'Flying'],
#    'abilities': ['Big Pecks', 'Keen Eye', 'Tangled Feet'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 16,
#     'cap': False,
#     'evos': ['Pidgeotto'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Pidgeotto',
#    'hp': 63,
#    'atk': 60,
#    'def': 55,
#    'spa': 50,
#    'spd': 50,
#    'spe': 71,
#    'weight': 30,
#    'height': 1.1,
#    'types': ['Normal', 'Flying'],
#    'abilities': ['Big Pecks', 'Keen Eye', 'Tangled Feet'],
#    'formats': [],
#    'oob': {'dex_number': 17,
#     'cap': False,
#     'evos': ['Pidgeot'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Pidgeot',
#    'hp': 83,
#    'atk': 80,
#    'def': 75,
#    'spa': 70,
#    'spd': 70,
#    'spe': 101,
#    'weight': 39.5,
#    'height': 1.5,
#    'types': ['Normal', 'Flying'],
#    'abilities': ['Big Pecks', 'Keen Eye', 'Tangled Feet'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 18,
#     'cap': False,
#     'evos': [],
#     'alts': ['Pidgeot-Mega'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Rattata',
#    'hp': 30,
#    'atk': 56,
#    'def': 35,
#    'spa': 25,
#    'spd': 35,
#    'spe': 72,
#    'weight': 3.5,
#    'height': 0.3,
#    'types': ['Normal'],
#    'abilities': ['Guts', 'Hustle', 'Run Away'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 19,
#     'cap': False,
#     'evos': ['Raticate', 'Raticate-Alola-Totem'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Raticate',
#    'hp': 55,
#    'atk': 81,
#    'def': 60,
#    'spa': 50,
#    'spd': 70,
#    'spe': 97,
#    'weight': 18.5,
#    'height': 0.7,
#    'types': ['Normal'],
#    'abilities': ['Guts', 'Hustle', 'Run Away'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 20,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Spearow',
#    'hp': 40,
#    'atk': 60,
#    'def': 30,
#    'spa': 31,
#    'spd': 31,
#    'spe': 70,
#    'weight': 2,
#    'height': 0.3,
#    'types': ['Normal', 'Flying'],
#    'abilities': ['Keen Eye', 'Sniper'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 21,
#     'cap': False,
#     'evos': ['Fearow'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Fearow',
#    'hp': 65,
#    'atk': 90,
#    'def': 65,
#    'spa': 61,
#    'spd': 61,
#    'spe': 100,
#    'weight': 38,
#    'height': 1.2,
#    'types': ['Normal', 'Flying'],
#    'abilities': ['Keen Eye', 'Sniper'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 22,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Ekans',
#    'hp': 35,
#    'atk': 60,
#    'def': 44,
#    'spa': 40,
#    'spd': 54,
#    'spe': 55,
#    'weight': 6.9,
#    'height': 2,
#    'types': ['Poison'],
#    'abilities': ['Intimidate', 'Shed Skin', 'Unnerve'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 23,
#     'cap': False,
#     'evos': ['Arbok'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Arbok',
#    'hp': 60,
#    'atk': 95,
#    'def': 69,
#    'spa': 65,
#    'spd': 79,
#    'spe': 80,
#    'weight': 65,
#    'height': 3.5,
#    'types': ['Poison'],
#    'abilities': ['Intimidate', 'Shed Skin', 'Unnerve'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 24,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Pikachu',
#    'hp': 35,
#    'atk': 55,
#    'def': 40,
#    'spa': 50,
#    'spd': 50,
#    'spe': 90,
#    'weight': 6,
#    'height': 0.4,
#    'types': ['Electric'],
#    'abilities': ['Lightning Rod', 'Static'],
#    'formats': [],
#    'oob': {'dex_number': 25,
#     'cap': False,
#     'evos': ['Raichu', 'Raichu-Alola'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Raichu',
#    'hp': 60,
#    'atk': 90,
#    'def': 55,
#    'spa': 90,
#    'spd': 80,
#    'spe': 110,
#    'weight': 30,
#    'height': 0.8,
#    'types': ['Electric'],
#    'abilities': ['Lightning Rod', 'Static'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 26,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Sandshrew',
#    'hp': 50,
#    'atk': 75,
#    'def': 85,
#    'spa': 20,
#    'spd': 30,
#    'spe': 40,
#    'weight': 12,
#    'height': 0.6,
#    'types': ['Ground'],
#    'abilities': ['Sand Rush', 'Sand Veil'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 27,
#     'cap': False,
#     'evos': ['Sandslash'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Sandslash',
#    'hp': 75,
#    'atk': 100,
#    'def': 110,
#    'spa': 45,
#    'spd': 55,
#    'spe': 65,
#    'weight': 29.5,
#    'height': 1,
#    'types': ['Ground'],
#    'abilities': ['Sand Rush', 'Sand Veil'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 28,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Nidoran-F',
#    'hp': 55,
#    'atk': 47,
#    'def': 52,
#    'spa': 40,
#    'spd': 40,
#    'spe': 41,
#    'weight': 7,
#    'height': 0.4,
#    'types': ['Poison'],
#    'abilities': ['Hustle', 'Poison Point', 'Rivalry'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 29,
#     'cap': False,
#     'evos': ['Nidorina'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Nidorina',
#    'hp': 70,
#    'atk': 62,
#    'def': 67,
#    'spa': 55,
#    'spd': 55,
#    'spe': 56,
#    'weight': 20,
#    'height': 0.8,
#    'types': ['Poison'],
#    'abilities': ['Hustle', 'Poison Point', 'Rivalry'],
#    'formats': [],
#    'oob': {'dex_number': 30,
#     'cap': False,
#     'evos': ['Nidoqueen'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Nidoqueen',
#    'hp': 90,
#    'atk': 92,
#    'def': 87,
#    'spa': 75,
#    'spd': 85,
#    'spe': 76,
#    'weight': 60,
#    'height': 1.3,
#    'types': ['Poison', 'Ground'],
#    'abilities': ['Poison Point', 'Rivalry', 'Sheer Force'],
#    'formats': ['RU'],
#    'oob': {'dex_number': 31,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Nidoran-M',
#    'hp': 46,
#    'atk': 57,
#    'def': 40,
#    'spa': 40,
#    'spd': 40,
#    'spe': 50,
#    'weight': 9,
#    'height': 0.5,
#    'types': ['Poison'],
#    'abilities': ['Hustle', 'Poison Point', 'Rivalry'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 32,
#     'cap': False,
#     'evos': ['Nidorino'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Nidorino',
#    'hp': 61,
#    'atk': 72,
#    'def': 57,
#    'spa': 55,
#    'spd': 55,
#    'spe': 65,
#    'weight': 19.5,
#    'height': 0.9,
#    'types': ['Poison'],
#    'abilities': ['Hustle', 'Poison Point', 'Rivalry'],
#    'formats': [],
#    'oob': {'dex_number': 33,
#     'cap': False,
#     'evos': ['Nidoking'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Nidoking',
#    'hp': 81,
#    'atk': 102,
#    'def': 77,
#    'spa': 85,
#    'spd': 75,
#    'spe': 85,
#    'weight': 62,
#    'height': 1.4,
#    'types': ['Poison', 'Ground'],
#    'abilities': ['Poison Point', 'Rivalry', 'Sheer Force'],
#    'formats': ['UU'],
#    'oob': {'dex_number': 34,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Clefairy',
#    'hp': 70,
#    'atk': 45,
#    'def': 48,
#    'spa': 60,
#    'spd': 65,
#    'spe': 35,
#    'weight': 7.5,
#    'height': 0.6,
#    'types': ['Fairy'],
#    'abilities': ['Cute Charm', 'Friend Guard', 'Magic Guard'],
#    'formats': ['PU'],
#    'oob': {'dex_number': 35,
#     'cap': False,
#     'evos': ['Clefable'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Clefable',
#    'hp': 95,
#    'atk': 70,
#    'def': 73,
#    'spa': 95,
#    'spd': 90,
#    'spe': 60,
#    'weight': 40,
#    'height': 1.3,
#    'types': ['Fairy'],
#    'abilities': ['Cute Charm', 'Magic Guard', 'Unaware'],
#    'formats': ['OU'],
#    'oob': {'dex_number': 36,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Vulpix',
#    'hp': 38,
#    'atk': 41,
#    'def': 40,
#    'spa': 50,
#    'spd': 65,
#    'spe': 65,
#    'weight': 9.9,
#    'height': 0.6,
#    'types': ['Fire'],
#    'abilities': ['Drought', 'Flash Fire'],
#    'formats': [],
#    'oob': {'dex_number': 37,
#     'cap': False,
#     'evos': ['Ninetales'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Ninetales',
#    'hp': 73,
#    'atk': 76,
#    'def': 75,
#    'spa': 81,
#    'spd': 100,
#    'spe': 100,
#    'weight': 19.9,
#    'height': 1.1,
#    'types': ['Fire'],
#    'abilities': ['Drought', 'Flash Fire'],
#    'formats': ['RU'],
#    'oob': {'dex_number': 38,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Jigglypuff',
#    'hp': 115,
#    'atk': 45,
#    'def': 20,
#    'spa': 45,
#    'spd': 25,
#    'spe': 20,
#    'weight': 5.5,
#    'height': 0.5,
#    'types': ['Normal', 'Fairy'],
#    'abilities': ['Competitive', 'Cute Charm', 'Friend Guard'],
#    'formats': [],
#    'oob': {'dex_number': 39,
#     'cap': False,
#     'evos': ['Wigglytuff'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Wigglytuff',
#    'hp': 140,
#    'atk': 70,
#    'def': 45,
#    'spa': 85,
#    'spd': 50,
#    'spe': 45,
#    'weight': 12,
#    'height': 1,
#    'types': ['Normal', 'Fairy'],
#    'abilities': ['Competitive', 'Cute Charm', 'Frisk'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 40,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Zubat',
#    'hp': 40,
#    'atk': 45,
#    'def': 35,
#    'spa': 30,
#    'spd': 40,
#    'spe': 55,
#    'weight': 7.5,
#    'height': 0.8,
#    'types': ['Poison', 'Flying'],
#    'abilities': ['Infiltrator', 'Inner Focus'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 41,
#     'cap': False,
#     'evos': ['Golbat'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Golbat',
#    'hp': 75,
#    'atk': 80,
#    'def': 70,
#    'spa': 65,
#    'spd': 75,
#    'spe': 90,
#    'weight': 55,
#    'height': 1.6,
#    'types': ['Poison', 'Flying'],
#    'abilities': ['Infiltrator', 'Inner Focus'],
#    'formats': ['NU'],
#    'oob': {'dex_number': 42,
#     'cap': False,
#     'evos': ['Crobat'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Oddish',
#    'hp': 45,
#    'atk': 50,
#    'def': 55,
#    'spa': 75,
#    'spd': 65,
#    'spe': 30,
#    'weight': 5.4,
#    'height': 0.5,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Run Away'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 43,
#     'cap': False,
#     'evos': ['Gloom'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Gloom',
#    'hp': 60,
#    'atk': 65,
#    'def': 70,
#    'spa': 85,
#    'spd': 75,
#    'spe': 40,
#    'weight': 8.6,
#    'height': 0.8,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Stench'],
#    'formats': [],
#    'oob': {'dex_number': 44,
#     'cap': False,
#     'evos': ['Bellossom', 'Vileplume'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Vileplume',
#    'hp': 75,
#    'atk': 80,
#    'def': 85,
#    'spa': 110,
#    'spd': 90,
#    'spe': 50,
#    'weight': 18.6,
#    'height': 1.2,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Effect Spore'],
#    'formats': ['NUBL'],
#    'oob': {'dex_number': 45,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Paras',
#    'hp': 35,
#    'atk': 70,
#    'def': 55,
#    'spa': 45,
#    'spd': 55,
#    'spe': 25,
#    'weight': 5.4,
#    'height': 0.3,
#    'types': ['Bug', 'Grass'],
#    'abilities': ['Damp', 'Dry Skin', 'Effect Spore'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 46,
#     'cap': False,
#     'evos': ['Parasect'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Parasect',
#    'hp': 60,
#    'atk': 95,
#    'def': 80,
#    'spa': 60,
#    'spd': 80,
#    'spe': 30,
#    'weight': 29.5,
#    'height': 1,
#    'types': ['Bug', 'Grass'],
#    'abilities': ['Damp', 'Dry Skin', 'Effect Spore'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 47,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Venonat',
#    'hp': 60,
#    'atk': 55,
#    'def': 50,
#    'spa': 40,
#    'spd': 55,
#    'spe': 45,
#    'weight': 30,
#    'height': 1,
#    'types': ['Bug', 'Poison'],
#    'abilities': ['Compound Eyes', 'Run Away', 'Tinted Lens'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 48,
#     'cap': False,
#     'evos': ['Venomoth'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Venomoth',
#    'hp': 70,
#    'atk': 65,
#    'def': 60,
#    'spa': 90,
#    'spd': 75,
#    'spe': 90,
#    'weight': 12.5,
#    'height': 1.5,
#    'types': ['Bug', 'Poison'],
#    'abilities': ['Shield Dust', 'Tinted Lens', 'Wonder Skin'],
#    'formats': ['RUBL'],
#    'oob': {'dex_number': 49,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Diglett',
#    'hp': 10,
#    'atk': 55,
#    'def': 25,
#    'spa': 35,
#    'spd': 45,
#    'spe': 95,
#    'weight': 0.8,
#    'height': 0.2,
#    'types': ['Ground'],
#    'abilities': ['Arena Trap', 'Sand Force', 'Sand Veil'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 50,
#     'cap': False,
#     'evos': ['Dugtrio'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Dugtrio',
#    'hp': 35,
#    'atk': 100,
#    'def': 50,
#    'spa': 50,
#    'spd': 70,
#    'spe': 120,
#    'weight': 33.3,
#    'height': 0.7,
#    'types': ['Ground'],
#    'abilities': ['Arena Trap', 'Sand Force', 'Sand Veil'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 51,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Meowth',
#    'hp': 40,
#    'atk': 45,
#    'def': 35,
#    'spa': 40,
#    'spd': 40,
#    'spe': 90,
#    'weight': 4.2,
#    'height': 0.4,
#    'types': ['Normal'],
#    'abilities': ['Pickup', 'Technician', 'Unnerve'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 52,
#     'cap': False,
#     'evos': ['Persian'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Persian',
#    'hp': 65,
#    'atk': 70,
#    'def': 60,
#    'spa': 65,
#    'spd': 65,
#    'spe': 115,
#    'weight': 32,
#    'height': 1,
#    'types': ['Normal'],
#    'abilities': ['Limber', 'Technician', 'Unnerve'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 53,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Psyduck',
#    'hp': 50,
#    'atk': 52,
#    'def': 48,
#    'spa': 65,
#    'spd': 50,
#    'spe': 55,
#    'weight': 19.6,
#    'height': 0.8,
#    'types': ['Water'],
#    'abilities': ['Cloud Nine', 'Damp', 'Swift Swim'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 54,
#     'cap': False,
#     'evos': ['Golduck'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Golduck',
#    'hp': 80,
#    'atk': 82,
#    'def': 78,
#    'spa': 95,
#    'spd': 80,
#    'spe': 85,
#    'weight': 76.6,
#    'height': 1.7,
#    'types': ['Water'],
#    'abilities': ['Cloud Nine', 'Damp', 'Swift Swim'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 55,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Mankey',
#    'hp': 40,
#    'atk': 80,
#    'def': 35,
#    'spa': 35,
#    'spd': 45,
#    'spe': 70,
#    'weight': 28,
#    'height': 0.5,
#    'types': ['Fighting'],
#    'abilities': ['Anger Point', 'Defiant', 'Vital Spirit'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 56,
#     'cap': False,
#     'evos': ['Primeape'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Primeape',
#    'hp': 65,
#    'atk': 105,
#    'def': 60,
#    'spa': 60,
#    'spd': 70,
#    'spe': 95,
#    'weight': 32,
#    'height': 1,
#    'types': ['Fighting'],
#    'abilities': ['Anger Point', 'Defiant', 'Vital Spirit'],
#    'formats': ['PU'],
#    'oob': {'dex_number': 57,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Growlithe',
#    'hp': 55,
#    'atk': 70,
#    'def': 45,
#    'spa': 70,
#    'spd': 50,
#    'spe': 60,
#    'weight': 19,
#    'height': 0.7,
#    'types': ['Fire'],
#    'abilities': ['Flash Fire', 'Intimidate', 'Justified'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 58,
#     'cap': False,
#     'evos': ['Arcanine'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Arcanine',
#    'hp': 90,
#    'atk': 110,
#    'def': 80,
#    'spa': 100,
#    'spd': 80,
#    'spe': 95,
#    'weight': 155,
#    'height': 1.9,
#    'types': ['Fire'],
#    'abilities': ['Flash Fire', 'Intimidate', 'Justified'],
#    'formats': ['RU'],
#    'oob': {'dex_number': 59,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Poliwag',
#    'hp': 40,
#    'atk': 50,
#    'def': 40,
#    'spa': 40,
#    'spd': 40,
#    'spe': 90,
#    'weight': 12.4,
#    'height': 0.6,
#    'types': ['Water'],
#    'abilities': ['Damp', 'Swift Swim', 'Water Absorb'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 60,
#     'cap': False,
#     'evos': ['Poliwhirl'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Poliwhirl',
#    'hp': 65,
#    'atk': 65,
#    'def': 65,
#    'spa': 50,
#    'spd': 50,
#    'spe': 90,
#    'weight': 20,
#    'height': 1,
#    'types': ['Water'],
#    'abilities': ['Damp', 'Swift Swim', 'Water Absorb'],
#    'formats': [],
#    'oob': {'dex_number': 61,
#     'cap': False,
#     'evos': ['Politoed', 'Poliwrath'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Poliwrath',
#    'hp': 90,
#    'atk': 95,
#    'def': 95,
#    'spa': 70,
#    'spd': 90,
#    'spe': 70,
#    'weight': 54,
#    'height': 1.3,
#    'types': ['Water', 'Fighting'],
#    'abilities': ['Damp', 'Swift Swim', 'Water Absorb'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 62,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Abra',
#    'hp': 25,
#    'atk': 20,
#    'def': 15,
#    'spa': 105,
#    'spd': 55,
#    'spe': 90,
#    'weight': 19.5,
#    'height': 0.9,
#    'types': ['Psychic'],
#    'abilities': ['Inner Focus', 'Magic Guard', 'Synchronize'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 63,
#     'cap': False,
#     'evos': ['Kadabra'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Kadabra',
#    'hp': 40,
#    'atk': 35,
#    'def': 30,
#    'spa': 120,
#    'spd': 70,
#    'spe': 105,
#    'weight': 56.5,
#    'height': 1.3,
#    'types': ['Psychic'],
#    'abilities': ['Inner Focus', 'Magic Guard', 'Synchronize'],
#    'formats': [],
#    'oob': {'dex_number': 64,
#     'cap': False,
#     'evos': ['Alakazam'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Alakazam',
#    'hp': 55,
#    'atk': 50,
#    'def': 45,
#    'spa': 135,
#    'spd': 95,
#    'spe': 120,
#    'weight': 48,
#    'height': 1.5,
#    'types': ['Psychic'],
#    'abilities': ['Inner Focus', 'Magic Guard', 'Synchronize'],
#    'formats': ['UUBL'],
#    'oob': {'dex_number': 65,
#     'cap': False,
#     'evos': [],
#     'alts': ['Alakazam-Mega'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Machop',
#    'hp': 70,
#    'atk': 80,
#    'def': 50,
#    'spa': 35,
#    'spd': 35,
#    'spe': 35,
#    'weight': 19.5,
#    'height': 0.8,
#    'types': ['Fighting'],
#    'abilities': ['Guts', 'No Guard', 'Steadfast'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 66,
#     'cap': False,
#     'evos': ['Machoke'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Machoke',
#    'hp': 80,
#    'atk': 100,
#    'def': 70,
#    'spa': 50,
#    'spd': 60,
#    'spe': 45,
#    'weight': 70.5,
#    'height': 1.5,
#    'types': ['Fighting'],
#    'abilities': ['Guts', 'No Guard', 'Steadfast'],
#    'formats': [],
#    'oob': {'dex_number': 67,
#     'cap': False,
#     'evos': ['Machamp'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Machamp',
#    'hp': 90,
#    'atk': 130,
#    'def': 80,
#    'spa': 65,
#    'spd': 85,
#    'spe': 55,
#    'weight': 130,
#    'height': 1.6,
#    'types': ['Fighting'],
#    'abilities': ['Guts', 'No Guard', 'Steadfast'],
#    'formats': ['RU'],
#    'oob': {'dex_number': 68,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Bellsprout',
#    'hp': 50,
#    'atk': 75,
#    'def': 35,
#    'spa': 70,
#    'spd': 30,
#    'spe': 40,
#    'weight': 4,
#    'height': 0.7,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Gluttony'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 69,
#     'cap': False,
#     'evos': ['Weepinbell'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Weepinbell',
#    'hp': 65,
#    'atk': 90,
#    'def': 50,
#    'spa': 85,
#    'spd': 45,
#    'spe': 55,
#    'weight': 6.4,
#    'height': 1,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Gluttony'],
#    'formats': [],
#    'oob': {'dex_number': 70,
#     'cap': False,
#     'evos': ['Victreebel'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Victreebel',
#    'hp': 80,
#    'atk': 105,
#    'def': 65,
#    'spa': 100,
#    'spd': 70,
#    'spe': 70,
#    'weight': 15.5,
#    'height': 1.7,
#    'types': ['Grass', 'Poison'],
#    'abilities': ['Chlorophyll', 'Gluttony'],
#    'formats': ['PU'],
#    'oob': {'dex_number': 71,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Tentacool',
#    'hp': 40,
#    'atk': 40,
#    'def': 35,
#    'spa': 50,
#    'spd': 100,
#    'spe': 70,
#    'weight': 45.5,
#    'height': 0.9,
#    'types': ['Water', 'Poison'],
#    'abilities': ['Clear Body', 'Liquid Ooze', 'Rain Dish'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 72,
#     'cap': False,
#     'evos': ['Tentacruel'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Tentacruel',
#    'hp': 80,
#    'atk': 70,
#    'def': 65,
#    'spa': 80,
#    'spd': 120,
#    'spe': 100,
#    'weight': 55,
#    'height': 1.6,
#    'types': ['Water', 'Poison'],
#    'abilities': ['Clear Body', 'Liquid Ooze', 'Rain Dish'],
#    'formats': ['UU'],
#    'oob': {'dex_number': 73,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Geodude',
#    'hp': 40,
#    'atk': 80,
#    'def': 100,
#    'spa': 30,
#    'spd': 30,
#    'spe': 20,
#    'weight': 20,
#    'height': 0.4,
#    'types': ['Rock', 'Ground'],
#    'abilities': ['Rock Head', 'Sand Veil', 'Sturdy'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 74,
#     'cap': False,
#     'evos': ['Graveler'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Graveler',
#    'hp': 55,
#    'atk': 95,
#    'def': 115,
#    'spa': 45,
#    'spd': 45,
#    'spe': 35,
#    'weight': 105,
#    'height': 1,
#    'types': ['Rock', 'Ground'],
#    'abilities': ['Rock Head', 'Sand Veil', 'Sturdy'],
#    'formats': [],
#    'oob': {'dex_number': 75,
#     'cap': False,
#     'evos': ['Golem'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Golem',
#    'hp': 80,
#    'atk': 120,
#    'def': 130,
#    'spa': 55,
#    'spd': 65,
#    'spe': 45,
#    'weight': 300,
#    'height': 1.4,
#    'types': ['Rock', 'Ground'],
#    'abilities': ['Rock Head', 'Sand Veil', 'Sturdy'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 76,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Ponyta',
#    'hp': 50,
#    'atk': 85,
#    'def': 55,
#    'spa': 65,
#    'spd': 65,
#    'spe': 90,
#    'weight': 30,
#    'height': 1,
#    'types': ['Fire'],
#    'abilities': ['Flame Body', 'Flash Fire', 'Run Away'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 77,
#     'cap': False,
#     'evos': ['Rapidash'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Rapidash',
#    'hp': 65,
#    'atk': 100,
#    'def': 70,
#    'spa': 80,
#    'spd': 80,
#    'spe': 105,
#    'weight': 95,
#    'height': 1.7,
#    'types': ['Fire'],
#    'abilities': ['Flame Body', 'Flash Fire', 'Run Away'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 78,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Slowpoke',
#    'hp': 90,
#    'atk': 65,
#    'def': 65,
#    'spa': 40,
#    'spd': 40,
#    'spe': 15,
#    'weight': 36,
#    'height': 1.2,
#    'types': ['Water', 'Psychic'],
#    'abilities': ['Oblivious', 'Own Tempo', 'Regenerator'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 79,
#     'cap': False,
#     'evos': ['Slowbro', 'Slowking'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Slowbro',
#    'hp': 95,
#    'atk': 75,
#    'def': 110,
#    'spa': 100,
#    'spd': 80,
#    'spe': 30,
#    'weight': 78.5,
#    'height': 1.6,
#    'types': ['Water', 'Psychic'],
#    'abilities': ['Oblivious', 'Own Tempo', 'Regenerator'],
#    'formats': ['RU'],
#    'oob': {'dex_number': 80,
#     'cap': False,
#     'evos': [],
#     'alts': ['Slowbro-Mega'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Magnemite',
#    'hp': 25,
#    'atk': 35,
#    'def': 70,
#    'spa': 95,
#    'spd': 55,
#    'spe': 45,
#    'weight': 6,
#    'height': 0.3,
#    'types': ['Electric', 'Steel'],
#    'abilities': ['Analytic', 'Magnet Pull', 'Sturdy'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 81,
#     'cap': False,
#     'evos': ['Magneton'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Magneton',
#    'hp': 50,
#    'atk': 60,
#    'def': 95,
#    'spa': 120,
#    'spd': 70,
#    'spe': 70,
#    'weight': 60,
#    'height': 1,
#    'types': ['Electric', 'Steel'],
#    'abilities': ['Analytic', 'Magnet Pull', 'Sturdy'],
#    'formats': ['UU'],
#    'oob': {'dex_number': 82,
#     'cap': False,
#     'evos': ['Magnezone'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': "Farfetch'd",
#    'hp': 52,
#    'atk': 90,
#    'def': 55,
#    'spa': 58,
#    'spd': 62,
#    'spe': 60,
#    'weight': 15,
#    'height': 0.8,
#    'types': ['Normal', 'Flying'],
#    'abilities': ['Defiant', 'Inner Focus', 'Keen Eye'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 83,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Doduo',
#    'hp': 35,
#    'atk': 85,
#    'def': 45,
#    'spa': 35,
#    'spd': 35,
#    'spe': 75,
#    'weight': 39.2,
#    'height': 1.4,
#    'types': ['Normal', 'Flying'],
#    'abilities': ['Early Bird', 'Run Away', 'Tangled Feet'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 84,
#     'cap': False,
#     'evos': ['Dodrio'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Dodrio',
#    'hp': 60,
#    'atk': 110,
#    'def': 70,
#    'spa': 60,
#    'spd': 60,
#    'spe': 110,
#    'weight': 85.2,
#    'height': 1.8,
#    'types': ['Normal', 'Flying'],
#    'abilities': ['Early Bird', 'Run Away', 'Tangled Feet'],
#    'formats': ['PU'],
#    'oob': {'dex_number': 85,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Seel',
#    'hp': 65,
#    'atk': 45,
#    'def': 55,
#    'spa': 45,
#    'spd': 70,
#    'spe': 45,
#    'weight': 90,
#    'height': 1.1,
#    'types': ['Water'],
#    'abilities': ['Hydration', 'Ice Body', 'Thick Fat'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 86,
#     'cap': False,
#     'evos': ['Dewgong'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Dewgong',
#    'hp': 90,
#    'atk': 70,
#    'def': 80,
#    'spa': 70,
#    'spd': 95,
#    'spe': 70,
#    'weight': 120,
#    'height': 1.7,
#    'types': ['Water', 'Ice'],
#    'abilities': ['Hydration', 'Ice Body', 'Thick Fat'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 87,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Grimer',
#    'hp': 80,
#    'atk': 80,
#    'def': 50,
#    'spa': 40,
#    'spd': 50,
#    'spe': 25,
#    'weight': 30,
#    'height': 0.9,
#    'types': ['Poison'],
#    'abilities': ['Poison Touch', 'Stench', 'Sticky Hold'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 88,
#     'cap': False,
#     'evos': ['Muk'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Muk',
#    'hp': 105,
#    'atk': 105,
#    'def': 75,
#    'spa': 65,
#    'spd': 100,
#    'spe': 50,
#    'weight': 30,
#    'height': 1.2,
#    'types': ['Poison'],
#    'abilities': ['Poison Touch', 'Stench', 'Sticky Hold'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 89,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Shellder',
#    'hp': 30,
#    'atk': 65,
#    'def': 100,
#    'spa': 45,
#    'spd': 25,
#    'spe': 40,
#    'weight': 4,
#    'height': 0.3,
#    'types': ['Water'],
#    'abilities': ['Overcoat', 'Shell Armor', 'Skill Link'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 90,
#     'cap': False,
#     'evos': ['Cloyster'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Cloyster',
#    'hp': 50,
#    'atk': 95,
#    'def': 180,
#    'spa': 85,
#    'spd': 45,
#    'spe': 70,
#    'weight': 132.5,
#    'height': 1.5,
#    'types': ['Water', 'Ice'],
#    'abilities': ['Overcoat', 'Shell Armor', 'Skill Link'],
#    'formats': ['RU'],
#    'oob': {'dex_number': 91,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Gastly',
#    'hp': 30,
#    'atk': 35,
#    'def': 30,
#    'spa': 100,
#    'spd': 35,
#    'spe': 80,
#    'weight': 0.1,
#    'height': 1.3,
#    'types': ['Ghost', 'Poison'],
#    'abilities': ['Levitate'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 92,
#     'cap': False,
#     'evos': ['Haunter'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Haunter',
#    'hp': 45,
#    'atk': 50,
#    'def': 45,
#    'spa': 115,
#    'spd': 55,
#    'spe': 95,
#    'weight': 0.1,
#    'height': 1.6,
#    'types': ['Ghost', 'Poison'],
#    'abilities': ['Levitate'],
#    'formats': ['PU'],
#    'oob': {'dex_number': 93,
#     'cap': False,
#     'evos': ['Gengar'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Gengar',
#    'hp': 60,
#    'atk': 65,
#    'def': 60,
#    'spa': 130,
#    'spd': 75,
#    'spe': 110,
#    'weight': 40.5,
#    'height': 1.5,
#    'types': ['Ghost', 'Poison'],
#    'abilities': ['Cursed Body'],
#    'formats': ['UU'],
#    'oob': {'dex_number': 94,
#     'cap': False,
#     'evos': [],
#     'alts': ['Gengar-Mega'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Onix',
#    'hp': 35,
#    'atk': 45,
#    'def': 160,
#    'spa': 30,
#    'spd': 45,
#    'spe': 70,
#    'weight': 210,
#    'height': 8.8,
#    'types': ['Rock', 'Ground'],
#    'abilities': ['Rock Head', 'Sturdy', 'Weak Armor'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 95,
#     'cap': False,
#     'evos': ['Steelix'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Drowzee',
#    'hp': 60,
#    'atk': 48,
#    'def': 45,
#    'spa': 43,
#    'spd': 90,
#    'spe': 42,
#    'weight': 32.4,
#    'height': 1,
#    'types': ['Psychic'],
#    'abilities': ['Forewarn', 'Inner Focus', 'Insomnia'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 96,
#     'cap': False,
#     'evos': ['Hypno'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Hypno',
#    'hp': 85,
#    'atk': 73,
#    'def': 70,
#    'spa': 73,
#    'spd': 115,
#    'spe': 67,
#    'weight': 75.6,
#    'height': 1.6,
#    'types': ['Psychic'],
#    'abilities': ['Forewarn', 'Inner Focus', 'Insomnia'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 97,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Krabby',
#    'hp': 30,
#    'atk': 105,
#    'def': 90,
#    'spa': 25,
#    'spd': 25,
#    'spe': 50,
#    'weight': 6.5,
#    'height': 0.4,
#    'types': ['Water'],
#    'abilities': ['Hyper Cutter', 'Sheer Force', 'Shell Armor'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 98,
#     'cap': False,
#     'evos': ['Kingler'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Kingler',
#    'hp': 55,
#    'atk': 130,
#    'def': 115,
#    'spa': 50,
#    'spd': 50,
#    'spe': 75,
#    'weight': 60,
#    'height': 1.3,
#    'types': ['Water'],
#    'abilities': ['Hyper Cutter', 'Sheer Force', 'Shell Armor'],
#    'formats': ['PUBL'],
#    'oob': {'dex_number': 99,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Voltorb',
#    'hp': 40,
#    'atk': 30,
#    'def': 50,
#    'spa': 55,
#    'spd': 55,
#    'spe': 100,
#    'weight': 10.4,
#    'height': 0.5,
#    'types': ['Electric'],
#    'abilities': ['Aftermath', 'Soundproof', 'Static'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 100,
#     'cap': False,
#     'evos': ['Electrode'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Electrode',
#    'hp': 60,
#    'atk': 50,
#    'def': 70,
#    'spa': 80,
#    'spd': 80,
#    'spe': 150,
#    'weight': 66.6,
#    'height': 1.2,
#    'types': ['Electric'],
#    'abilities': ['Aftermath', 'Soundproof', 'Static'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 101,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Exeggcute',
#    'hp': 60,
#    'atk': 40,
#    'def': 80,
#    'spa': 60,
#    'spd': 45,
#    'spe': 40,
#    'weight': 2.5,
#    'height': 0.4,
#    'types': ['Grass', 'Psychic'],
#    'abilities': ['Chlorophyll', 'Harvest'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 102,
#     'cap': False,
#     'evos': ['Exeggutor', 'Exeggutor-Alola'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Exeggutor',
#    'hp': 95,
#    'atk': 95,
#    'def': 85,
#    'spa': 125,
#    'spd': 75,
#    'spe': 55,
#    'weight': 120,
#    'height': 2,
#    'types': ['Grass', 'Psychic'],
#    'abilities': ['Chlorophyll', 'Harvest'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 103,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Cubone',
#    'hp': 50,
#    'atk': 50,
#    'def': 95,
#    'spa': 40,
#    'spd': 50,
#    'spe': 35,
#    'weight': 6.5,
#    'height': 0.4,
#    'types': ['Ground'],
#    'abilities': ['Battle Armor', 'Lightning Rod', 'Rock Head'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 104,
#     'cap': False,
#     'evos': ['Marowak', 'Marowak-Alola', 'Marowak-Alola-Totem'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Marowak',
#    'hp': 60,
#    'atk': 80,
#    'def': 110,
#    'spa': 50,
#    'spd': 80,
#    'spe': 45,
#    'weight': 45,
#    'height': 1,
#    'types': ['Ground'],
#    'abilities': ['Battle Armor', 'Lightning Rod', 'Rock Head'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 105,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Hitmonlee',
#    'hp': 50,
#    'atk': 120,
#    'def': 53,
#    'spa': 35,
#    'spd': 110,
#    'spe': 87,
#    'weight': 49.8,
#    'height': 1.5,
#    'types': ['Fighting'],
#    'abilities': ['Limber', 'Reckless', 'Unburden'],
#    'formats': ['NU'],
#    'oob': {'dex_number': 106,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Hitmonchan',
#    'hp': 50,
#    'atk': 105,
#    'def': 79,
#    'spa': 35,
#    'spd': 110,
#    'spe': 76,
#    'weight': 50.2,
#    'height': 1.4,
#    'types': ['Fighting'],
#    'abilities': ['Inner Focus', 'Iron Fist', 'Keen Eye'],
#    'formats': ['PU'],
#    'oob': {'dex_number': 107,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Lickitung',
#    'hp': 90,
#    'atk': 55,
#    'def': 75,
#    'spa': 60,
#    'spd': 75,
#    'spe': 30,
#    'weight': 65.5,
#    'height': 1.2,
#    'types': ['Normal'],
#    'abilities': ['Cloud Nine', 'Oblivious', 'Own Tempo'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 108,
#     'cap': False,
#     'evos': ['Lickilicky'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Koffing',
#    'hp': 40,
#    'atk': 65,
#    'def': 95,
#    'spa': 60,
#    'spd': 45,
#    'spe': 35,
#    'weight': 1,
#    'height': 0.6,
#    'types': ['Poison'],
#    'abilities': ['Levitate'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 109,
#     'cap': False,
#     'evos': ['Weezing'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Weezing',
#    'hp': 65,
#    'atk': 90,
#    'def': 120,
#    'spa': 85,
#    'spd': 70,
#    'spe': 60,
#    'weight': 9.5,
#    'height': 1.2,
#    'types': ['Poison'],
#    'abilities': ['Levitate'],
#    'formats': ['NU'],
#    'oob': {'dex_number': 110,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Rhyhorn',
#    'hp': 80,
#    'atk': 85,
#    'def': 95,
#    'spa': 30,
#    'spd': 30,
#    'spe': 25,
#    'weight': 115,
#    'height': 1,
#    'types': ['Ground', 'Rock'],
#    'abilities': ['Lightning Rod', 'Reckless', 'Rock Head'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 111,
#     'cap': False,
#     'evos': ['Rhydon'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Rhydon',
#    'hp': 105,
#    'atk': 130,
#    'def': 120,
#    'spa': 45,
#    'spd': 45,
#    'spe': 40,
#    'weight': 120,
#    'height': 1.9,
#    'types': ['Ground', 'Rock'],
#    'abilities': ['Lightning Rod', 'Reckless', 'Rock Head'],
#    'formats': ['NU'],
#    'oob': {'dex_number': 112,
#     'cap': False,
#     'evos': ['Rhyperior'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Chansey',
#    'hp': 250,
#    'atk': 5,
#    'def': 5,
#    'spa': 35,
#    'spd': 105,
#    'spe': 50,
#    'weight': 34.6,
#    'height': 1.1,
#    'types': ['Normal'],
#    'abilities': ['Healer', 'Natural Cure', 'Serene Grace'],
#    'formats': ['OU'],
#    'oob': {'dex_number': 113,
#     'cap': False,
#     'evos': ['Blissey'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Tangela',
#    'hp': 65,
#    'atk': 55,
#    'def': 115,
#    'spa': 100,
#    'spd': 40,
#    'spe': 60,
#    'weight': 35,
#    'height': 1,
#    'types': ['Grass'],
#    'abilities': ['Chlorophyll', 'Leaf Guard', 'Regenerator'],
#    'formats': ['PU'],
#    'oob': {'dex_number': 114,
#     'cap': False,
#     'evos': ['Tangrowth'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Kangaskhan',
#    'hp': 105,
#    'atk': 95,
#    'def': 80,
#    'spa': 40,
#    'spd': 80,
#    'spe': 90,
#    'weight': 80,
#    'height': 2.2,
#    'types': ['Normal'],
#    'abilities': ['Early Bird', 'Inner Focus', 'Scrappy'],
#    'formats': ['PU'],
#    'oob': {'dex_number': 115,
#     'cap': False,
#     'evos': [],
#     'alts': ['Kangaskhan-Mega'],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Horsea',
#    'hp': 30,
#    'atk': 40,
#    'def': 70,
#    'spa': 70,
#    'spd': 25,
#    'spe': 60,
#    'weight': 8,
#    'height': 0.4,
#    'types': ['Water'],
#    'abilities': ['Damp', 'Sniper', 'Swift Swim'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 116,
#     'cap': False,
#     'evos': ['Seadra'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Seadra',
#    'hp': 55,
#    'atk': 65,
#    'def': 95,
#    'spa': 95,
#    'spd': 45,
#    'spe': 85,
#    'weight': 25,
#    'height': 1.2,
#    'types': ['Water'],
#    'abilities': ['Damp', 'Poison Point', 'Sniper'],
#    'formats': [],
#    'oob': {'dex_number': 117,
#     'cap': False,
#     'evos': ['Kingdra'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Goldeen',
#    'hp': 45,
#    'atk': 67,
#    'def': 60,
#    'spa': 35,
#    'spd': 50,
#    'spe': 63,
#    'weight': 15,
#    'height': 0.6,
#    'types': ['Water'],
#    'abilities': ['Lightning Rod', 'Swift Swim', 'Water Veil'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 118,
#     'cap': False,
#     'evos': ['Seaking'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Seaking',
#    'hp': 80,
#    'atk': 92,
#    'def': 65,
#    'spa': 65,
#    'spd': 80,
#    'spe': 68,
#    'weight': 39,
#    'height': 1.3,
#    'types': ['Water'],
#    'abilities': ['Lightning Rod', 'Swift Swim', 'Water Veil'],
#    'formats': ['Untiered'],
#    'oob': {'dex_number': 119,
#     'cap': False,
#     'evos': [],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM', 'SS']}},
#   {'name': 'Staryu',
#    'hp': 30,
#    'atk': 45,
#    'def': 55,
#    'spa': 70,
#    'spd': 55,
#    'spe': 85,
#    'weight': 34.5,
#    'height': 0.8,
#    'types': ['Water'],
#    'abilities': ['Analytic', 'Illuminate', 'Natural Cure'],
#    'formats': ['LC'],
#    'oob': {'dex_number': 120,
#     'cap': False,
#     'evos': ['Starmie'],
#     'alts': [],
#     'genfamily': ['RB', 'GS', 'RS', 'DP', 'BW', 'XY', 'SM']}},
#   {'name': 'Starmie',
#    'hp': 60,
#    'atk': 75,
#    'def': 85,
#    'spa': 100,
#    'spd': 85,
#    'spe': 115,
#    'weight': 80,
#    'height': 1.1,
#    'types': ['Water', 'Psychic'],
#    'abilities': ['Analytic', 'Illuminate', 'Natural Cure'],
#    'formats': ['UU'],
#    'oob': {'dex_number': 121,
#     'cap': False,
#     'evos': [],
# ...
#    'description': 'If held by a Kangaskhan, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Latiasite',
#    'description': 'If held by a Latias, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Latiosite',
#    'description': 'If held by a Latios, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Lopunnite',
#    'description': 'If held by a Lopunny, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Lucarionite',
#    'description': 'If held by a Lucario, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Manectite',
#    'description': 'If held by a Manectric, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Mawilite',
#    'description': 'If held by a Mawile, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Medichamite',
#    'description': 'If held by a Medicham, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Metagrossite',
#    'description': 'If held by a Metagross, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Mewtwonite X',
#    'description': 'If held by a Mewtwo, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Mewtwonite Y',
#    'description': 'If held by a Mewtwo, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Pidgeotite',
#    'description': 'If held by a Pidgeot, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Pinsirite',
#    'description': 'If held by a Pinsir, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Red Orb',
#    'description': 'If held by a Groudon, this item triggers its Primal Reversion in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Sablenite',
#    'description': 'If held by a Sableye, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Salamencite',
#    'description': 'If held by a Salamence, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Sceptilite',
#    'description': 'If held by a Sceptile, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Scizorite',
#    'description': 'If held by a Scizor, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Sharpedonite',
#    'description': 'If held by a Sharpedo, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Slowbronite',
#    'description': 'If held by a Slowbro, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Steelixite',
#    'description': 'If held by a Steelix, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Swampertite',
#    'description': 'If held by a Swampert, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Tyranitarite',
#    'description': 'If held by a Tyranitar, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Venusaurite',
#    'description': 'If held by a Venusaur, this item allows it to Mega Evolve in battle.',
#    'cap': False,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Assault Vest',
#    'description': "Holder's Sp. Def is 1.5x, but it can only select damaging moves.",
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Jaw Fossil',
#    'description': 'Can be revived into Tyrunt.',
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Kee Berry',
#    'description': "Raises holder's Defense by 1 stage after it is hit by a physical attack. Single use.",
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Luminous Moss',
#    'description': "Raises holder's Sp. Def by 1 stage if hit by a Water-type attack. Single use.",
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Maranga Berry',
#    'description': "Raises holder's Sp. Def by 1 stage after it is hit by a special attack. Single use.",
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Pixie Plate',
#    'description': "Holder's Fairy-type attacks have 1.2x power. Judgment is Fairy type.",
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Roseli Berry',
#    'description': 'Halves damage taken from a supereffective Fairy-type attack. Single use.',
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Sachet',
#    'description': 'Evolves Spritzee into Aromatisse when traded.',
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Safety Goggles',
#    'description': 'Holder is immune to powder moves and damage from Sandstorm or Hail.',
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Sail Fossil',
#    'description': 'Can be revived into Amaura.',
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Snowball',
#    'description': "Raises holder's Attack by 1 if hit by an Ice-type attack. Single use.",
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Weakness Policy',
#    'description': 'If holder is hit super effectively, raises Attack, Sp. Atk by 2 stages. Single use.',
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Whipped Dream',
#    'description': 'Evolves Swirlix into Slurpuff when traded.',
#    'cap': False,
#    'genfamily': ['XY', 'SM', 'SS']},
#   {'name': 'Crucibellite',
#    'description': 'If held by a Crucibelle, this item allows it to Mega Evolve in battle.',
#    'cap': True,
#    'genfamily': ['XY', 'SM']},
#   {'name': 'Aloraichium Z',
#    'description': 'If held by an Alolan Raichu with Thunderbolt, it can use Stoked Sparksurfer.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Buginium Z',
#    'description': 'If holder has a Bug move, this item allows it to use a Bug Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Darkinium Z',
#    'description': 'If holder has a Dark move, this item allows it to use a Dark Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Decidium Z',
#    'description': 'If held by a Decidueye with Spirit Shackle, it can use Sinister Arrow Raid.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Dragonium Z',
#    'description': 'If holder has a Dragon move, this item allows it to use a Dragon Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Eevium Z',
#    'description': 'If held by an Eevee with Last Resort, it can use Extreme Evoboost.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Electrium Z',
#    'description': 'If holder has an Electric move, this item allows it to use an Electric Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Fairium Z',
#    'description': 'If holder has a Fairy move, this item allows it to use a Fairy Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Fightinium Z',
#    'description': 'If holder has a Fighting move, this item allows it to use a Fighting Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Firium Z',
#    'description': 'If holder has a Fire move, this item allows it to use a Fire Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Flyinium Z',
#    'description': 'If holder has a Flying move, this item allows it to use a Flying Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Ghostium Z',
#    'description': 'If holder has a Ghost move, this item allows it to use a Ghost Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Grassium Z',
#    'description': 'If holder has a Grass move, this item allows it to use a Grass Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Groundium Z',
#    'description': 'If holder has a Ground move, this item allows it to use a Ground Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Ice Stone',
#    'description': 'Evolves certain species of Pokemon when used.',
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Icium Z',
#    'description': 'If holder has an Ice move, this item allows it to use an Ice Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Incinium Z',
#    'description': 'If held by an Incineroar with Darkest Lariat, it can use Malicious Moonsault.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Kommonium Z',
#    'description': 'If held by a Kommo-o with Clanging Scales, it can use Clangorous Soulblaze.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Lunalium Z',
#    'description': 'Lunala or Dawn Wings Necrozma with Moongeist Beam can use a special Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Lycanium Z',
#    'description': 'If held by a Lycanroc forme with Stone Edge, it can use Splintered Stormshards.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Marshadium Z',
#    'description': 'If held by Marshadow with Spectral Thief, it can use Soul-Stealing 7-Star Strike.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Mewnium Z',
#    'description': 'If held by a Mew with Psychic, it can use Genesis Supernova.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Mimikium Z',
#    'description': "If held by a Mimikyu with Play Rough, it can use Let's Snuggle Forever.",
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Normalium Z',
#    'description': 'If holder has a Normal move, this item allows it to use a Normal Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Pikanium Z',
#    'description': 'If held by a Pikachu with Volt Tackle, it can use Catastropika.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Pikashunium Z',
#    'description': 'If held by cap Pikachu with Thunderbolt, it can use 10,000,000 Volt Thunderbolt.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Poisonium Z',
#    'description': 'If holder has a Poison move, this item allows it to use a Poison Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Primarium Z',
#    'description': 'If held by a Primarina with Sparkling Aria, it can use Oceanic Operetta.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Psychium Z',
#    'description': 'If holder has a Psychic move, this item allows it to use a Psychic Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Rockium Z',
#    'description': 'If holder has a Rock move, this item allows it to use a Rock Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Snorlium Z',
#    'description': 'If held by a Snorlax with Giga Impact, it can use Pulverizing Pancake.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Solganium Z',
#    'description': 'Solgaleo or Dusk Mane Necrozma with Sunsteel Strike can use a special Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Steelium Z',
#    'description': 'If holder has a Steel move, this item allows it to use a Steel Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Tapunium Z',
#    'description': "If held by a Tapu with Nature's Madness, it can use Guardian of Alola.",
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Ultranecrozium Z',
#    'description': 'Dusk Mane/Dawn Wings Necrozma: Ultra Burst, then Z-Move w/ Photon Geyser.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Waterium Z',
#    'description': 'If holder has a Water move, this item allows it to use a Water Z-Move.',
#    'cap': False,
#    'genfamily': ['SM']},
#   {'name': 'Adrenaline Orb',
#    'description': "Raises holder's Speed by 1 stage if it gets affected by Intimidate. Single use.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Beast Ball',
#    'description': 'A special Poke Ball designed to catch Ultra Beasts.',
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Bottle Cap',
#    'description': "Used for Hyper Training. One of a Pokemon's stats is calculated with an IV of 31.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Bug Memory',
#    'description': "Holder's Multi-Attack is Bug type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Dark Memory',
#    'description': "Holder's Multi-Attack is Dark type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Dragon Memory',
#    'description': "Holder's Multi-Attack is Dragon type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Electric Memory',
#    'description': "Holder's Multi-Attack is Electric type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Electric Seed',
#    'description': "If the terrain is Electric Terrain, raises holder's Defense by 1 stage. Single use.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Fairy Memory',
#    'description': "Holder's Multi-Attack is Fairy type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Fighting Memory',
#    'description': "Holder's Multi-Attack is Fighting type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Fire Memory',
#    'description': "Holder's Multi-Attack is Fire type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Flying Memory',
#    'description': "Holder's Multi-Attack is Flying type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Ghost Memory',
#    'description': "Holder's Multi-Attack is Ghost type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Gold Bottle Cap',
#    'description': "Used for Hyper Training. All of a Pokemon's stats are calculated with an IV of 31.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Grass Memory',
#    'description': "Holder's Multi-Attack is Grass type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Grassy Seed',
#    'description': "If the terrain is Grassy Terrain, raises holder's Defense by 1 stage. Single use.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Ground Memory',
#    'description': "Holder's Multi-Attack is Ground type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Ice Memory',
#    'description': "Holder's Multi-Attack is Ice type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Misty Seed',
#    'description': "If the terrain is Misty Terrain, raises holder's Sp. Def by 1 stage. Single use.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Poison Memory',
#    'description': "Holder's Multi-Attack is Poison type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Protective Pads',
#    'description': "Holder's moves are protected from adverse contact effects, except Pickpocket.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Psychic Memory',
#    'description': "Holder's Multi-Attack is Psychic type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Psychic Seed',
#    'description': "If the terrain is Psychic Terrain, raises holder's Sp. Def by 1 stage. Single use.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Rock Memory',
#    'description': "Holder's Multi-Attack is Rock type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Steel Memory',
#    'description': "Holder's Multi-Attack is Steel type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Terrain Extender',
#    'description': "Holder's use of Electric/Grassy/Misty/Psychic Terrain lasts 8 turns instead of 5.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']},
#   {'name': 'Water Memory',
#    'description': "Holder's Multi-Attack is Water type.",
#    'cap': False,
#    'genfamily': ['SM', 'SS']}]}
